# %%
# Importation des bibliothèque
import numpy as np 
import pandas as pd 
import datetime as dt

# %%
# Fais apparaitre l'ensemble des informations
pd.set_option("display.max_rows", 5000)
pd.set_option("display.max_column", 70)
pd.set_option("display.max_colwidth", 100)

# %%
# Lecture des données
data = pd.read_csv('../data/raw/dirty_cafe_sales.csv')
data = data.sort_values(by='Transaction Date')
data
# Out:
#      Transaction ID      Item Quantity Price Per Unit Total Spent  \
# 7152    TXN_6566716    Coffee    ERROR            2.0         2.0
# 8885    TXN_1581562    Coffee        2            2.0         4.0
# 1806    TXN_2192787  Sandwich        5            4.0        20.0
# 2244    TXN_5358805    Coffee        5            2.0        10.0
# 7285    TXN_1604072    Coffee        2            2.0         4.0
# ...             ...       ...      ...            ...         ...
# 9769    TXN_9686177      Cake        3            3.0         9.0
# 9833    TXN_5536245  Smoothie        4            4.0        16.0
# 9885    TXN_4659954       NaN        3            4.0        12.0
# 9931    TXN_8344810  Smoothie        2            4.0         8.0
# 9988    TXN_9594133      Cake        5            3.0         NaN
#
#       Payment Method  Location Transaction Date
# 7152     Credit Card       NaN       2023-01-01
# 8885            Cash  In-store       2023-01-01
# 1806            Cash  In-store       2023-01-01
# 2244  Digital Wallet     ERROR       2023-01-01
# 7285             NaN       NaN       2023-01-01
# ...              ...       ...              ...
# 9769             NaN  In-store              NaN
# 9833            Cash       NaN              NaN
# 9885     Credit Card  In-store              NaN
# 9931             NaN   UNKNOWN              NaN
# 9988           ERROR       NaN              NaN
#
# [10000 rows x 8 columns]

# %% [markdown]
# ### Nettoyage de la dataset

# %%
# Remplacer les ERROR et UNKNOW par des valeur null
data = data.replace(['ERROR', 'UNKNOWN'], np.nan)
data
# Out:
#      Transaction ID      Item Quantity Price Per Unit Total Spent  \
# 7152    TXN_6566716    Coffee      NaN            2.0         2.0
# 8885    TXN_1581562    Coffee        2            2.0         4.0
# 1806    TXN_2192787  Sandwich        5            4.0        20.0
# 2244    TXN_5358805    Coffee        5            2.0        10.0
# 7285    TXN_1604072    Coffee        2            2.0         4.0
# ...             ...       ...      ...            ...         ...
# 9769    TXN_9686177      Cake        3            3.0         9.0
# 9833    TXN_5536245  Smoothie        4            4.0        16.0
# 9885    TXN_4659954       NaN        3            4.0        12.0
# 9931    TXN_8344810  Smoothie        2            4.0         8.0
# 9988    TXN_9594133      Cake        5            3.0         NaN
#
#       Payment Method  Location Transaction Date
# 7152     Credit Card       NaN       2023-01-01
# 8885            Cash  In-store       2023-01-01
# 1806            Cash  In-store       2023-01-01
# 2244  Digital Wallet       NaN       2023-01-01
# 7285             NaN       NaN       2023-01-01
# ...              ...       ...              ...
# 9769             NaN  In-store              NaN
# 9833            Cash       NaN              NaN
# 9885     Credit Card  In-store              NaN
# 9931             NaN       NaN              NaN
# 9988             NaN       NaN              NaN
#
# [10000 rows x 8 columns]

# %%
# Changer les str en float et les dates en datetime
data['Price Per Unit'] = data['Price Per Unit'].astype(float)
data['Total Spent'] = data['Total Spent'].astype(float)
data['Quantity'] = data['Quantity'].astype(float)
# format que date sans l'heure
data['Transaction Date'] = pd.to_datetime(data['Transaction Date']).dt.date
data
# Out:
#      Transaction ID      Item  Quantity  Price Per Unit  Total Spent  \
# 7152    TXN_6566716    Coffee       NaN             2.0          2.0
# 8885    TXN_1581562    Coffee       2.0             2.0          4.0
# 1806    TXN_2192787  Sandwich       5.0             4.0         20.0
# 2244    TXN_5358805    Coffee       5.0             2.0         10.0
# 7285    TXN_1604072    Coffee       2.0             2.0          4.0
# ...             ...       ...       ...             ...          ...
# 9769    TXN_9686177      Cake       3.0             3.0          9.0
# 9833    TXN_5536245  Smoothie       4.0             4.0         16.0
# 9885    TXN_4659954       NaN       3.0             4.0         12.0
# 9931    TXN_8344810  Smoothie       2.0             4.0          8.0
# 9988    TXN_9594133      Cake       5.0             3.0          NaN
#
#       Payment Method  Location Transaction Date
# 7152     Credit Card       NaN       2023-01-01
# 8885            Cash  In-store       2023-01-01
# 1806            Cash  In-store       2023-01-01
# 2244  Digital Wallet       NaN       2023-01-01
# 7285             NaN       NaN       2023-01-01
# ...              ...       ...              ...
# 9769             NaN  In-store              NaT
# 9833            Cash       NaN              NaT
# 9885     Credit Card  In-store              NaT
# 9931             NaN       NaN              NaT
# 9988             NaN       NaN              NaT
#
# [10000 rows x 8 columns]

# %%
# Trouver le prix unitaire moyen par leur nom de 'Item'
item_price_dict = data.set_index('Item')['Price Per Unit'].to_dict()
data['Price Per Unit'] = data.apply(lambda row: item_price_dict[row['Item']] if pd.isna(row['Price Per Unit']) else row['Price Per Unit'], axis=1)
data
# Out:
#      Transaction ID      Item  Quantity  Price Per Unit  Total Spent  \
# 7152    TXN_6566716    Coffee       NaN             2.0          2.0
# 8885    TXN_1581562    Coffee       2.0             2.0          4.0
# 1806    TXN_2192787  Sandwich       5.0             4.0         20.0
# 2244    TXN_5358805    Coffee       5.0             2.0         10.0
# 7285    TXN_1604072    Coffee       2.0             2.0          4.0
# ...             ...       ...       ...             ...          ...
# 9769    TXN_9686177      Cake       3.0             3.0          9.0
# 9833    TXN_5536245  Smoothie       4.0             4.0         16.0
# 9885    TXN_4659954       NaN       3.0             4.0         12.0
# 9931    TXN_8344810  Smoothie       2.0             4.0          8.0
# 9988    TXN_9594133      Cake       5.0             3.0          NaN
#
#       Payment Method  Location Transaction Date
# 7152     Credit Card       NaN       2023-01-01
# 8885            Cash  In-store       2023-01-01
# 1806            Cash  In-store       2023-01-01
# 2244  Digital Wallet       NaN       2023-01-01
# 7285             NaN       NaN       2023-01-01
# ...              ...       ...              ...
# 9769             NaN  In-store              NaT
# 9833            Cash       NaN              NaT
# 9885     Credit Card  In-store              NaT
# 9931             NaN       NaN              NaT
# 9988             NaN       NaN              NaT
#
# [10000 rows x 8 columns]

# %%
# Remplacer les valeur null par la quantité en faisant un Total spent / Price Per Unit pour trouver la quantité
data['Quantity'] = data['Total Spent'] / data['Price Per Unit']
data
# Out:
#      Transaction ID      Item  Quantity  Price Per Unit  Total Spent  \
# 7152    TXN_6566716    Coffee       1.0             2.0          2.0
# 8885    TXN_1581562    Coffee       2.0             2.0          4.0
# 1806    TXN_2192787  Sandwich       5.0             4.0         20.0
# 2244    TXN_5358805    Coffee       5.0             2.0         10.0
# 7285    TXN_1604072    Coffee       2.0             2.0          4.0
# ...             ...       ...       ...             ...          ...
# 9769    TXN_9686177      Cake       3.0             3.0          9.0
# 9833    TXN_5536245  Smoothie       4.0             4.0         16.0
# 9885    TXN_4659954       NaN       3.0             4.0         12.0
# 9931    TXN_8344810  Smoothie       2.0             4.0          8.0
# 9988    TXN_9594133      Cake       NaN             3.0          NaN
#
#       Payment Method  Location Transaction Date
# 7152     Credit Card       NaN       2023-01-01
# 8885            Cash  In-store       2023-01-01
# 1806            Cash  In-store       2023-01-01
# 2244  Digital Wallet       NaN       2023-01-01
# 7285             NaN       NaN       2023-01-01
# ...              ...       ...              ...
# 9769             NaN  In-store              NaT
# 9833            Cash       NaN              NaT
# 9885     Credit Card  In-store              NaT
# 9931             NaN       NaN              NaT
# 9988             NaN       NaN              NaT
#
# [10000 rows x 8 columns]

# %%
# Exportation des données nettoyés ! :)
data.to_csv('../data/processed/cleaned_cafe_sales.csv', index=False)

# %%
data.describe()
# Out:
#           Quantity  Price Per Unit  Total Spent
# count  9498.000000    10000.000000  9498.000000
# mean      3.019267        2.953350     8.924352
# std       1.421518        1.279517     6.009919
# min       0.500000        1.000000     1.000000
# 25%       2.000000        2.000000     4.000000
# 50%       3.000000        3.000000     8.000000
# 75%       4.000000        4.000000    12.000000
# max       6.250000        5.000000    25.000000
